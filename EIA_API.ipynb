# %%
import requests
import pandas as pd

API_KEY = "ijlrhEG5WYFjMVik6QQMv3TnY5jIZuJ1l1FiRLPK"

# Example: total U.S. electricity generation by year
url = f"https://api.eia.gov/v2/natural-gas/pri/rescom/data/?frequency=monthly&data[0]=value&start=2023-01&end=2025-04&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000&api_key={API_KEY}"

response = requests.get(url)
data = response.json()

# Check structure
print(data.keys())

# Convert to pandas DataFrame
df = pd.DataFrame(data["response"]["data"])

df.head()
